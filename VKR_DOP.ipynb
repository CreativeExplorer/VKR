# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras as keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Activation
from pandas import read_excel, DataFrame, Series
from tensorflow.keras.models import Sequential
from numpy.random import seed
#import warnings
#warnings.filterwarnings("ignore")

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score

# %%
#Загружаем первый датасет (базальтопластик) и посмотрим на названия столбцов
df = pd.read_excel("Итог.xlsx")
df.shape
# Out:
# (922, 14)

# %%
df1=df.drop(['Unnamed: 0'],axis=1)

# %%
# Сформируем входы и выход для модели
tv = df1['Соотношение матрица-наполнитель']
tr_v = df1.loc[:, df1.columns != 'Соотношение матрица-наполнитель']
# Разбиваем выборки на обучающую и тестовую
x_train, x_test, y_train, y_test = train_test_split(tr_v, tv, test_size = 0.3, random_state = 14)

# %%
tr_v
# Out:
#      Плотность, кг/м3  модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0         2030.000000             738.736842                    50.000000
# 1         2030.000000             738.736842                   129.000000
# 2         2030.000000             753.000000                   111.860000
# 3         2000.000000             748.000000                   111.860000
# 4         1910.000000             807.000000                   111.860000
# ..                ...                    ...                          ...
# 917       1952.087902             912.855545                    86.992183
# 918       2050.089171             444.732634                   145.981978
# 919       1972.372865             416.836524                   110.533477
# 920       2066.799773             741.475517                   141.397963
# 921       1890.413468             417.316232                   129.183416
#
#      Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 0                          23.750000                284.615385
# 1                          21.250000                300.000000
# 2                          22.267857                284.615385
# 3                          22.267857                284.615385
# 4                          22.267857                284.615385
# ..                               ...                       ...
# 917                        20.123249                324.774576
# 918                        19.599769                254.215401
# 919                        23.957502                248.423047
# 920                        19.246945                275.779840
# 921                        27.474763                300.952708
#
#      Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 0                       210.000000                             70.000000
# 1                       210.000000                             70.000000
# 2                       210.000000                             70.000000
# 3                       210.000000                             70.000000
# 4                       210.000000                             70.000000
# ..                             ...                                   ...
# 917                     209.198700                             73.090961
# 918                     350.660830                             72.920827
# 919                     740.142791                             74.734344
# 920                     641.468152                             74.042708
# 921                     758.747882                             74.309704
#
#      Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 0                      3000.000000               220.000000
# 1                      3000.000000               220.000000
# 2                      3000.000000               220.000000
# 3                      3000.000000               220.000000
# 4                      3000.000000               220.000000
# ..                             ...                      ...
# 917                    2387.292495               125.007669
# 918                    2360.392784               117.730099
# 919                    2662.906040               236.606764
# 920                    2071.715856               197.126067
# 921                    2856.328932               194.754342
#
#      Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                     0     4.000000          60.000000
# 1                     0     5.000000          47.000000
# 2                     0     5.000000          57.000000
# 3                     0     5.000000          60.000000
# 4                     0     5.000000          70.000000
# ..                  ...          ...                ...
# 917                  90     9.076380          47.019770
# 918                  90    10.565614          53.750790
# 919                  90     4.161154          67.629684
# 920                  90     6.313201          58.261074
# 921                  90     6.078902          77.434468
#
# [922 rows x 12 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer, LabelEncoder, MinMaxScaler, StandardScaler

# %%
x_train.head()
# Out:
#      Плотность, кг/м3  модуль упругости, ГПа  Количество отвердителя, м.%  \
# 408       1918.505388             923.222626                   102.856973
# 866       2011.164986            1224.526540                   115.639182
# 518       2116.647950             833.967349                   102.944857
# 790       1964.864776            1140.391684                    96.812897
# 281       1931.881912            1110.896831                    62.620924
#
#      Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 408                        21.778325                304.152923
# 866                        18.218292                341.758888
# 518                        19.620920                233.750031
# 790                        21.572128                284.781260
# 281                        25.334082                294.211396
#
#      Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 408                      99.372553                             76.666930
# 866                     969.003020                             75.568206
# 518                      38.609529                             70.221071
# 790                     887.796828                             72.871322
# 281                     362.407115                             76.493768
#
#      Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 408                    2821.643613               189.650866
# 866                    3248.094836               224.963194
# 518                    3533.008496               254.612780
# 790                    2412.682294               283.565146
# 281                    2787.386492               136.548332
#
#      Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 408                   0     6.708062          41.984468
# 866                  90     6.010934          60.034399
# 518                  90     7.809148          63.137907
# 790                  90     3.640496          50.280645
# 281                   0     5.991188          48.635969

# %%
y_train
# Out:
# 408    2.254452
# 866    2.864568
# 518    5.295842
# 790    3.350539
# 281    3.307663
#          ...
# 327    3.048681
# 406    3.096419
# 268    3.223754
# 344    1.067339
# 619    2.519514
# Name: Соотношение матрица-наполнитель, Length: 645, dtype: float64

# %%
y_train.shape
# Out:
# (645,)

# %%
# Функция для сравнения результатов предсказаний с моделью, выдающей среднее значение по тестовой выборке
def mean_model(y_test):
    return [np.mean(y_test) for _ in range(len(y_test))]
y_pred_mean = mean_model(y_test)

# %%
value = [[x for x in range(0,5)],
         [x for x in range(10,15)],
         [x for x in range(20,25)]] 
value
# Out:
# [[0, 1, 2, 3, 4], [10, 11, 12, 13, 14], [20, 21, 22, 23, 24]]

# %%
value = np.array(value)         

print("Numpy array:", value)
sum = value.sum(axis=0)  
print("Mean:", sum / value.shape[0])
# Out:
# Numpy array: [[ 0  1  2  3  4]
#  [10 11 12 13 14]
#  [20 21 22 23 24]]
# Mean: [10. 11. 12. 13. 14.]

# %%
mean = x_train.mean(axis=0)
x_train -= mean

# %%
std = x_train.std(axis=0)
x_train /= std

# %%
def norm(x):
  return (x - mean) / std

x_train = norm(x_train);
x_test = norm(x_test);

# %%
# Приводим значения ответов в диапазон от 0 до 1
min_y = y_train.min()

y_train = y_train - min_y #смещаем ответы к 0, вычитая минимальное значение
max_y = y_train.max() #берем максимум от уже "опущенных" вниз на min_y данных 
y_train /= max_y #приводим к 1 обучающую выборку

#нормируем ответы проверочной выборки, используя статистику min_y и max_y обучающей 
y_test = y_test - min_y
y_test /= max_y

# %%
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu')),
model.add(Dense(32, activation='relu')),
model.add(Dense(1, activation='sigmoid')) # sigmoid, т.к. данные от 0 до 1

# %%
print(model.summary()) # архитектура нашей модели
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1664
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 16,193
# Trainable params: 16,193
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Т.к. задача регрессии, удобнее использовать mean square error(средне-квадратичная ошибка).
# В качестве метрики берем mean absolute error (средний модуль ошибки)
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
history = model.fit(x_train, 
                    y_train, 
                    epochs=100, 
                    validation_split=0.1, 
                    verbose=2)
# Out:
# Epoch 1/100
# 19/19 - 1s - loss: 0.0523 - mae: 0.1791 - val_loss: 0.0424 - val_mae: 0.1549 - 595ms/epoch - 31ms/step
# Epoch 2/100
# 19/19 - 0s - loss: 0.0395 - mae: 0.1615 - val_loss: 0.0815 - val_mae: 0.2517 - 30ms/epoch - 2ms/step
# Epoch 3/100
# 19/19 - 0s - loss: 0.0399 - mae: 0.1608 - val_loss: 0.0372 - val_mae: 0.1515 - 29ms/epoch - 2ms/step
# Epoch 4/100
# 19/19 - 0s - loss: 0.0356 - mae: 0.1519 - val_loss: 0.0369 - val_mae: 0.1526 - 28ms/epoch - 1ms/step
# Epoch 5/100
# 19/19 - 0s - loss: 0.0379 - mae: 0.1567 - val_loss: 0.0720 - val_mae: 0.2350 - 29ms/epoch - 2ms/step
# Epoch 6/100
# 19/19 - 0s - loss: 0.0366 - mae: 0.1540 - val_loss: 0.0372 - val_mae: 0.1523 - 28ms/epoch - 1ms/step
# Epoch 7/100
# 19/19 - 0s - loss: 0.0373 - mae: 0.1551 - val_loss: 0.0458 - val_mae: 0.1811 - 28ms/epoch - 1ms/step
# Epoch 8/100
# 19/19 - 0s - loss: 0.0372 - mae: 0.1553 - val_loss: 0.0396 - val_mae: 0.1632 - 28ms/epoch - 1ms/step
# Epoch 9/100
# 19/19 - 0s - loss: 0.0359 - mae: 0.1526 - val_loss: 0.0431 - val_mae: 0.1741 - 27ms/epoch - 1ms/step
# Epoch 10/100
# 19/19 - 0s - loss: 0.0356 - mae: 0.1523 - val_loss: 0.0467 - val_mae: 0.1835 - 27ms/epoch - 1ms/step
# Epoch 11/100
# 19/19 - 0s - loss: 0.0361 - mae: 0.1530 - val_loss: 0.0372 - val_mae: 0.1515 - 27ms/epoch - 1ms/step
# Epoch 12/100
# 19/19 - 0s - loss: 0.0358 - mae: 0.1524 - val_loss: 0.0388 - val_mae: 0.1603 - 27ms/epoch - 1ms/step
# Epoch 13/100
# 19/19 - 0s - loss: 0.0358 - mae: 0.1522 - val_loss: 0.0373 - val_mae: 0.1550 - 28ms/epoch - 1ms/step
# Epoch 14/100
# 19/19 - 0s - loss: 0.0353 - mae: 0.1513 - val_loss: 0.0395 - val_mae: 0.1628 - 29ms/epoch - 2ms/step
# Epoch 15/100
# 19/19 - 0s - loss: 0.0358 - mae: 0.1524 - val_loss: 0.0421 - val_mae: 0.1709 - 31ms/epoch - 2ms/step
# Epoch 16/100
# 19/19 - 0s - loss: 0.0355 - mae: 0.1522 - val_loss: 0.0421 - val_mae: 0.1707 - 30ms/epoch - 2ms/step
# Epoch 17/100
# 19/19 - 0s - loss: 0.0356 - mae: 0.1517 - val_loss: 0.0371 - val_mae: 0.1541 - 32ms/epoch - 2ms/step
# Epoch 18/100
# 19/19 - 0s - loss: 0.0358 - mae: 0.1521 - val_loss: 0.0384 - val_mae: 0.1590 - 54ms/epoch - 3ms/step
# Epoch 19/100
# 19/19 - 0s - loss: 0.0353 - mae: 0.1512 - val_loss: 0.0481 - val_mae: 0.1868 - 60ms/epoch - 3ms/step
# Epoch 20/100
# 19/19 - 0s - loss: 0.0354 - mae: 0.1520 - val_loss: 0.0370 - val_mae: 0.1535 - 70ms/epoch - 4ms/step
# Epoch 21/100
# 19/19 - 0s - loss: 0.0358 - mae: 0.1519 - val_loss: 0.0370 - val_mae: 0.1515 - 56ms/epoch - 3ms/step
# Epoch 22/100
# 19/19 - 0s - loss: 0.0356 - mae: 0.1526 - val_loss: 0.0381 - val_mae: 0.1581 - 40ms/epoch - 2ms/step
# Epoch 23/100
# 19/19 - 0s - loss: 0.0360 - mae: 0.1528 - val_loss: 0.0383 - val_mae: 0.1590 - 49ms/epoch - 3ms/step
# Epoch 24/100
# 19/19 - 0s - loss: 0.0356 - mae: 0.1518 - val_loss: 0.0382 - val_mae: 0.1582 - 50ms/epoch - 3ms/step
# Epoch 25/100
# 19/19 - 0s - loss: 0.0353 - mae: 0.1512 - val_loss: 0.0381 - val_mae: 0.1580 - 33ms/epoch - 2ms/step
# Epoch 26/100
# 19/19 - 0s - loss: 0.0353 - mae: 0.1511 - val_loss: 0.0384 - val_mae: 0.1589 - 39ms/epoch - 2ms/step
# Epoch 27/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 41ms/epoch - 2ms/step
# Epoch 28/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 37ms/epoch - 2ms/step
# Epoch 29/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 41ms/epoch - 2ms/step
# Epoch 30/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1598 - 43ms/epoch - 2ms/step
# Epoch 31/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 42ms/epoch - 2ms/step
# Epoch 32/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 52ms/epoch - 3ms/step
# Epoch 33/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1601 - 31ms/epoch - 2ms/step
# Epoch 34/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0388 - val_mae: 0.1604 - 43ms/epoch - 2ms/step
# Epoch 35/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1607 - 43ms/epoch - 2ms/step
# Epoch 36/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0387 - val_mae: 0.1600 - 30ms/epoch - 2ms/step
# Epoch 37/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1607 - 42ms/epoch - 2ms/step
# Epoch 38/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0388 - val_mae: 0.1604 - 43ms/epoch - 2ms/step
# Epoch 39/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0389 - val_mae: 0.1606 - 30ms/epoch - 2ms/step
# Epoch 40/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1600 - 38ms/epoch - 2ms/step
# Epoch 41/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 43ms/epoch - 2ms/step
# Epoch 42/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1510 - val_loss: 0.0386 - val_mae: 0.1596 - 45ms/epoch - 2ms/step
# Epoch 43/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 31ms/epoch - 2ms/step
# Epoch 44/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 41ms/epoch - 2ms/step
# Epoch 45/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1595 - 41ms/epoch - 2ms/step
# Epoch 46/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1601 - 35ms/epoch - 2ms/step
# Epoch 47/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 43ms/epoch - 2ms/step
# Epoch 48/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1599 - 42ms/epoch - 2ms/step
# Epoch 49/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1596 - 50ms/epoch - 3ms/step
# Epoch 50/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1599 - 49ms/epoch - 3ms/step
# Epoch 51/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1595 - 49ms/epoch - 3ms/step
# Epoch 52/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 59ms/epoch - 3ms/step
# Epoch 53/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 34ms/epoch - 2ms/step
# Epoch 54/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 37ms/epoch - 2ms/step
# Epoch 55/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1598 - 42ms/epoch - 2ms/step
# Epoch 56/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1599 - 35ms/epoch - 2ms/step
# Epoch 57/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0388 - val_mae: 0.1603 - 35ms/epoch - 2ms/step
# Epoch 58/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0389 - val_mae: 0.1607 - 42ms/epoch - 2ms/step
# Epoch 59/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0390 - val_mae: 0.1611 - 51ms/epoch - 3ms/step
# Epoch 60/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0391 - val_mae: 0.1614 - 53ms/epoch - 3ms/step
# Epoch 61/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1608 - 54ms/epoch - 3ms/step
# Epoch 62/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1605 - 42ms/epoch - 2ms/step
# Epoch 63/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0388 - val_mae: 0.1605 - 32ms/epoch - 2ms/step
# Epoch 64/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1608 - 35ms/epoch - 2ms/step
# Epoch 65/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1605 - 35ms/epoch - 2ms/step
# Epoch 66/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0388 - val_mae: 0.1605 - 35ms/epoch - 2ms/step
# Epoch 67/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1600 - 41ms/epoch - 2ms/step
# Epoch 68/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1596 - 33ms/epoch - 2ms/step
# Epoch 69/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1600 - 33ms/epoch - 2ms/step
# Epoch 70/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1599 - 34ms/epoch - 2ms/step
# Epoch 71/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 34ms/epoch - 2ms/step
# Epoch 72/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1601 - 34ms/epoch - 2ms/step
# Epoch 73/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1512 - val_loss: 0.0386 - val_mae: 0.1598 - 38ms/epoch - 2ms/step
# Epoch 74/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1593 - 40ms/epoch - 2ms/step
# Epoch 75/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0384 - val_mae: 0.1591 - 39ms/epoch - 2ms/step
# Epoch 76/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 47ms/epoch - 2ms/step
# Epoch 77/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 44ms/epoch - 2ms/step
# Epoch 78/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1592 - 37ms/epoch - 2ms/step
# Epoch 79/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1598 - 34ms/epoch - 2ms/step
# Epoch 80/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1595 - 36ms/epoch - 2ms/step
# Epoch 81/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1595 - 33ms/epoch - 2ms/step
# Epoch 82/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1599 - 35ms/epoch - 2ms/step
# Epoch 83/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1598 - 34ms/epoch - 2ms/step
# Epoch 84/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 33ms/epoch - 2ms/step
# Epoch 85/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1593 - 35ms/epoch - 2ms/step
# Epoch 86/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0384 - val_mae: 0.1591 - 33ms/epoch - 2ms/step
# Epoch 87/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1592 - 34ms/epoch - 2ms/step
# Epoch 88/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0384 - val_mae: 0.1589 - 35ms/epoch - 2ms/step
# Epoch 89/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0384 - val_mae: 0.1590 - 35ms/epoch - 2ms/step
# Epoch 90/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 35ms/epoch - 2ms/step
# Epoch 91/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1598 - 35ms/epoch - 2ms/step
# Epoch 92/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0388 - val_mae: 0.1603 - 34ms/epoch - 2ms/step
# Epoch 93/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0388 - val_mae: 0.1603 - 33ms/epoch - 2ms/step
# Epoch 94/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0389 - val_mae: 0.1606 - 33ms/epoch - 2ms/step
# Epoch 95/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0387 - val_mae: 0.1602 - 34ms/epoch - 2ms/step
# Epoch 96/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 35ms/epoch - 2ms/step
# Epoch 97/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1597 - 35ms/epoch - 2ms/step
# Epoch 98/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0386 - val_mae: 0.1596 - 34ms/epoch - 2ms/step
# Epoch 99/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1595 - 34ms/epoch - 2ms/step
# Epoch 100/100
# 19/19 - 0s - loss: 0.0352 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1594 - 33ms/epoch - 2ms/step

# %%
# оценим модель
scores = model.evaluate(x_test, y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 9/9 [==============================] - 0s 748us/step - loss: 0.0353 - mae: 0.1508
#
# mae: 15.08%

# %%
# Посмотрим на потери модели
history.history
# Out:
# {'loss': [0.05233633890748024,
#   0.03953559324145317,
#   0.03986550122499466,
#   0.03561887890100479,
#   0.037908557802438736,
#   0.036569930613040924,
#   0.03726664558053017,
#   0.03720264881849289,
#   0.03588676080107689,
#   0.03561196103692055,
#   0.03606870397925377,
#   0.03582903742790222,
#   0.035781145095825195,
#   0.03530556336045265,
#   0.03580714762210846,
#   0.035527776926755905,
#   0.035637110471725464,
#   0.035803135484457016,
#   0.0353333055973053,
#   0.03543112426996231,
#   0.035792432725429535,
#   0.03559068590402603,
#   0.03602130338549614,
#   0.035608671605587006,
#   0.03529609739780426,
#   0.035253848880529404,
#   0.03524152562022209,
#   0.035230208188295364,
#   0.0352071113884449,
#   0.03522099182009697,
#   0.03522171452641487,
#   0.035216957330703735,
#   0.0352204404771328,
#   0.03522096946835518,
#   0.03521846607327461,
#   0.0352184884250164,
#   0.03521428257226944,
#   0.03521200269460678,
#   0.03522172570228577,
#   0.035228386521339417,
#   0.035209640860557556,
#   0.03521457687020302,
#   0.035226959735155106,
#   0.03521493077278137,
#   0.03521702438592911,
#   0.03522448614239693,
#   0.035215508192777634,
#   0.03521578758955002,
#   0.035221029072999954,
#   0.035211704671382904,
#   0.035229865461587906,
#   0.03521212190389633,
#   0.035214439034461975,
#   0.035219598561525345,
#   0.03522908687591553,
#   0.03521721065044403,
#   0.0352192260324955,
#   0.035223957151174545,
#   0.03522008657455444,
#   0.035238053649663925,
#   0.035231057554483414,
#   0.035221364349126816,
#   0.03522772341966629,
#   0.035222116857767105,
#   0.03521965071558952,
#   0.035236064344644547,
#   0.0352192297577858,
#   0.03521387651562691,
#   0.035219401121139526,
#   0.035220831632614136,
#   0.0352189801633358,
#   0.035212695598602295,
#   0.15976382791996002,
#   0.15936978161334991,
#   0.15984226763248444,
#   0.16006939113140106,
#   0.1603843867778778,
#   0.16067112982273102,
#   0.16003836691379547,
#   0.1607409119606018,
#   0.1604134738445282,
#   0.1606064885854721,
#   0.1599898338317871,
#   0.15984348952770233,
#   0.1595543771982193,
#   0.15941067039966583,
#   0.1597256064414978,
#   0.1594884842634201,
#   0.1600634753704071,
#   0.15965744853019714,
#   0.15989135205745697,
#   0.15960745513439178,
#   0.15986362099647522,
#   0.15953469276428223,
#   0.15936395525932312,
#   0.15983636677265167,
#   0.15965068340301514,
#   0.15979936718940735,
#   0.15989255905151367,
#   0.16034471988677979,
#   0.16074392199516296,
#   0.16113613545894623,
#   0.16139689087867737,
#   0.16075050830841064,
#   0.1605452001094818,
#   0.1605025827884674,
#   0.160784512758255,
#   0.16053436696529388,
#   0.16046376526355743,
#   0.15996024012565613,
#   0.15964806079864502,
#   0.15997686982154846,
#   0.15989910066127777,
#   0.1598253846168518,
#   0.16005440056324005,
#   0.15975069999694824,
#   0.15931299328804016,
#   0.15911442041397095,
#   0.15984420478343964,
#   0.15943250060081482,
#   0.15922752022743225,
#   0.15984806418418884,
#   0.15945978462696075,
#   0.15952417254447937,
#   0.15990304946899414,
#   0.15981149673461914,
#   0.15967033803462982,
#   0.15933501720428467,
#   0.1590866893529892,
#   0.1591768115758896,
#   0.15893837809562683,
#   0.1589963138103485,
#   0.15938474237918854,
#   0.15982207655906677,
#   0.16026240587234497,
#   0.16030336916446686,
#   0.1606377512216568,
#   0.16015681624412537,
#   0.15969783067703247,
#   0.15974655747413635,
#   0.15962624549865723,
#   0.1594550758600235,
#   0.159407839179039]}

# %%
# Посмотрим на график потерь на тренировочной и тестовой выборках
def model_loss_plot(history):
 plt.figure(figsize = (17,5))
 plt.plot(history.history['loss'],
 label = 'ошибка на обучающей выборке')
 plt.plot(history.history['val_loss'],
 label = 'ошибка на тестовой выборке')
 plt.title('График потерь модели')
 plt.ylabel('Значение ошибки')
 plt.xlabel('Эпохи')
 plt.legend(['Oшибка на обучающей выборке', 'Ошибка на тестовой выборке'], loc='best')
 plt.show()
model_loss_plot(history)

# %%
# Зададим функцию для визуализации факт/прогноз для результатов моделей
# Посмотрим на график результата работы модели
def actual_and_predicted_plot(orig, predict, var, model_name): 
    plt.figure(figsize=(17,5))
    plt.title(f'Тестовые и прогнозные значения: {model_name}')
    plt.plot(orig, label = 'Тест')
    plt.plot(predict, label = 'Прогноз')
    plt.legend(loc = 'best')
    plt.ylabel(var)
    plt.xlabel('Количество наблюдений')
    plt.show()
actual_and_predicted_plot(y_test.values, model.predict(x_test.values), 'Cоотношение матрица/наполнитель', 'Keras_neuronet')
# Out:
# 9/9 [==============================] - 0s 873us/step

# %%
# Делаем прогноз. Возвращается копия предсказания в виде одномерного массива
pred = model.predict(x_test).flatten() 
pred
# Out:
# 9/9 [==============================] - 0s 623us/step
# array([0.51723135, 0.49516267, 0.5164262 , 0.5772693 , 0.53942424,
#        0.5020551 , 0.52891916, 0.5260096 , 0.5618414 , 0.50286543,
#        0.51872355, 0.54580957, 0.5085513 , 0.5225078 , 0.5207579 ,
#        0.52749646, 0.5281429 , 0.5002028 , 0.51189417, 0.54698473,
#        0.5278404 , 0.51464325, 0.5198934 , 0.5103236 , 0.52124995,
#        0.50624204, 0.48822588, 0.5001446 , 0.5288508 , 0.50350124,
#        0.52599853, 0.51916975, 0.5354087 , 0.5292628 , 0.5036443 ,
#        0.50706875, 0.5226035 , 0.5227219 , 0.5154685 , 0.5099693 ,
#        0.48611107, 0.53488773, 0.55225104, 0.5137096 , 0.5269725 ,
#        0.5050351 , 0.51420474, 0.5040384 , 0.52629554, 0.52500695,
#        0.5056922 , 0.5227216 , 0.5205833 , 0.51808316, 0.52337295,
#        0.52391106, 0.514511  , 0.51632977, 0.5110151 , 0.538458  ,
#        0.54065216, 0.5243444 , 0.516318  , 0.5441617 , 0.51480055,
#        0.56014866, 0.5240988 , 0.5157146 , 0.5093176 , 0.50079167,
#        0.5357148 , 0.53243476, 0.50544727, 0.5241497 , 0.54016125,
#        0.53104365, 0.53200454, 0.50696665, 0.50711894, 0.5112338 ,
#        0.51681393, 0.51731724, 0.5475791 , 0.51893616, 0.52254677,
#        0.49489775, 0.52662027], dtype=float32)

# %%
# Возвращаем к прежнему размеру
pred = pred * max_y + min_y 
y_test = y_test * max_y + min_y

# %%
pred
# Out:
# array([3.012905 , 2.907709 , 3.009067 , 3.299091 , 3.1186929, 2.9405634,
#        3.0686178, 3.0547488, 3.2255502, 2.944426 , 3.2447217, 2.9888203,
#        3.106774 , 2.9786263, 3.0160742, 3.0327303, 3.049816 , 2.9425437,
#        2.9473848, 2.9773755, 3.1858878, 2.9973068, 3.026583 , 3.0011184,
#        2.9278033, 2.981185 , 2.9740086, 3.077332 , 3.0212307, 3.135963 ,
#        3.0546434, 2.96901  , 3.0288537, 2.9976377, 3.025086 , 3.0566893,
#        2.9773147, 3.0934675, 3.005067 , 2.99145  , 2.9695783, 3.0882087,
#        3.0018728, 3.0259619, 3.057661 , 2.9742045, 2.9853537, 2.893453 ,
#        2.911757 , 2.9419785, 3.0347288, 3.007105 , 3.1162217, 3.0515466,
#        2.9540527, 3.0713615, 2.987119 , 2.9551706, 2.9632573, 3.0415876,
#        2.9414275, 3.0868149, 3.0379622, 3.1980853, 3.1068072, 3.0068424,
#        3.125048 , 2.990734 , 3.062268 , 3.0716848, 2.9716983, 2.945191 ,
#        2.9808974, 2.9650066, 3.2391212, 2.9362814, 3.0494711, 2.9678283,
#        3.1112554, 3.007243 , 2.9801583, 2.9991605, 3.144269 , 3.0599873,
#        3.0129552, 3.1695971, 2.9400527, 3.0271366, 3.1146255, 2.992797 ,
#        3.0171905, 3.0015855, 2.9823253, 2.9242542, 3.0213323, 3.0757647,
#        3.0365827, 2.9783816, 2.9680486, 3.1389308, 2.9694383, 2.9659324,
#        3.0504494, 3.0508788, 2.961628 , 3.0053945, 2.9982193, 3.062008 ,
#        2.96958  , 2.9653542, 3.0755188, 2.9928563, 2.9908087, 3.006953 ,
#        2.9255018, 3.0523522, 2.9356937, 2.9558122, 3.0720046, 3.0175774,
#        2.966067 , 3.1717882, 2.98892  , 2.9648964, 3.1191535, 3.0844567,
#        3.0839467, 3.3623493, 2.9924428, 3.111966 , 3.0275998, 2.9705126,
#        2.9654505, 3.134192 , 2.9701445, 3.0412073, 3.0783253, 3.0961494,
#        2.9870112, 2.941636 , 3.0145714, 3.0495882, 3.0432932, 2.9735818,
#        3.015569 , 3.1115146, 3.0102918, 2.9567885, 3.0370338, 3.0577028,
#        2.9889588, 2.9790347, 3.029317 , 3.169378 , 2.9840481, 3.0234866,
#        3.116712 , 2.9238553, 3.0078323, 3.025965 , 3.0202324, 2.9995327,
#        3.0787814, 2.985533 , 3.0615685, 2.932525 , 3.1176045, 3.0190358,
#        3.0117588, 3.1615844, 2.9635253, 2.9986029, 3.0411515, 3.0618026,
#        3.0514743, 2.987209 , 3.0820985, 3.059396 , 3.023329 , 2.9460635,
#        3.1603808, 3.0350826, 2.9438941, 3.0747976, 3.1054049, 2.9573205,
#        2.9925215, 2.999452 , 2.9848533, 3.1571906, 3.1398587, 2.9925027,
#        3.0343854, 3.059784 , 3.0707252, 3.003632 , 3.0640578, 3.081993 ,
#        3.1903756, 2.9459777, 3.0200179, 3.14913  , 2.9715292, 3.0380564,
#        3.029715 , 3.061836 , 3.0649176, 2.9317338, 2.987464 , 3.154732 ,
#        3.0634754, 3.0005682, 3.0255942, 2.9799774, 3.0320606, 2.9605215,
#        2.8746428, 2.9314566, 3.068292 , 2.9474568, 3.0546958, 3.0221448,
#        3.0995517, 3.0702558, 2.9481387, 2.9644623, 3.0385127, 3.0390768,
#        3.0045018, 2.9782884, 2.8645623, 3.0970685, 3.179835 , 2.9961176,
#        3.0593383, 2.9547684, 2.9984777, 2.9500172, 3.0561116, 3.0499692,
#        2.9579005, 3.0390754, 3.0288827, 3.0169652, 3.0421803, 3.0447454,
#        2.9999375, 3.0086071, 2.9832737, 3.114087 , 3.124546 , 3.0468109,
#        3.0085514, 3.1412752, 3.0013177, 3.2174811, 3.0456405, 3.0056748,
#        2.9751818, 2.934541 , 3.101011 , 3.0853758, 2.956733 , 3.045883 ,
#        3.122206 , 3.0787446, 3.083325 , 2.9639757, 2.9647014, 2.984316 ,
#        3.0109153, 3.0133142, 3.157565 , 3.0210314, 3.038242 , 2.9064462,
#        3.0576596], dtype=float32)

# %%
# Средний модуль отклонения 
err = np.mean(abs(pred - y_test))
print(err)
# Out:
# 0.7186024273820999

# %%
# Средняя цена по выборке
print(np.mean(y_test))
# Out:
# 2.898330911860213

# %%
# Разброс предсказаний может показать перекос, если есть
plt.scatter(y_test, pred) 
plt.xlabel('Правильные значение, $1K')
plt.ylabel('Предсказания, $1K')
plt.axis('equal')

plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-100, 100], [-100, 100])
plt.show()

# %%
#Разность предсказанного и правильного ответа
error = pred - y_test
#Построение гистограммы
plt.hist(abs(error), bins = 25)
plt.xlabel("Значение ошибки, $1K")
plt.ylabel("Количество")
plt.show()

# %%
model.save("model")
# Out:
# INFO:tensorflow:Assets written to: model\assets
